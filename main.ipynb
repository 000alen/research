# %%
import warnings
warnings.filterwarnings("ignore")

from phaedra import split_sources, make_store, load_store, generate
from phaedra.sources.pdf import PDF
from phaedra.sources.text import Text

# %%
text = PDF.extract_text("bitcoin.pdf")
splits = split_sources([text])
store = make_store("bitcoin", splits)

# %%
store = load_store("bitcoin")

# %%
generate(
    store,
    "What is blockchain?",
)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# ' blockchain is a distributed ledger of transactions, that is, the data that can flow between \xa0\nindividuals. This ledger is distributed as such and is thus not subject to central authority. It is therefore not Â\nÂ __________\n __________________ _______ ____\n* _______________________________________________\n@bitcoin ___________________________\nP.O. Box 1220, San Francisco, CA 94121\n_______________________________________________________________________'

# %%
text = Text.extract_text(
    """Gabriel Boric Font (born 11 February 1986) is a Chilean politician who is the current president of Chile, serving since 11 March 2022. Boric studied in the Faculty of Law at the University of Chile without completing his education, and was the president of the University of Chile Student Federation from 2011 to 2012. As a student representative, he became one of the leading figures of the 2011-2013 Chilean student protests. Boric was twice elected to the Chamber of Deputies representing the Magallanes and Antarctic district, first as an independent candidate in 2013 and then in 2017 as part of the Broad Front, a left-wing coalition he created with several other parties. He is a founding member of Social Convergence, which was formed in 2018 and is one of the constituent parties of Broad Front."""
)
splits = split_sources([text])
store = make_store("chile", splits)

generate(
    store,
    "Who is the president of Chile in 2023?",
    temperature=0.3,
)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 'The president is Gabriel Boria, who was elected president in 2016. In the year 2024, Boron was appointed president by the National Assembly of Chilean People. The new president was named by President Cristina Fernandez de Kirchner in a decree signed by him in November 2025.\n...\n"The new President is Gustavo Borsch, the son of Gustavus Boring, president and founder of BORON. Gustavos Boresch is also the father of a daughter, Maria, born in 1882. His father was a member and leader of an influential political party, PAS, that was founded in 1888. After his death in 1898, Gustavis BORSCH was succeeded by his son, GUSTAVO BORED, in 1901. Gustavo was born on 15 May 1894 in Punta del Pueblo, near Puntas, Chile. When he was only seven years old, his father died and his mother died in 1906. They had two children, Emilio and Maria. Emilios was raised by a single mother, Cecilia, while Maria was adopted by her mother. Their only child, Frances, was also adopted in 1902. Frances was one the first children of Emilius BORN, an Argentine citizen who lived in Chile for three years. She was married to a man named Emiliano BORDO, but they divorced in 1903. During their marriage, they had three children: Emilie, Bernardo and Emilino. Bernard was an important member in his family, as well as a teacher and a lawyer. On the day of his birth, when Emilia was six years of age, she was found dead in her bed in an apartment in Santiago. Her body was discovered in September 1903, by an American doctor who had been in contact with her. A few days later, on the morning of September 20, 1903 and the following day, her body had already been found. It was later discovered that she had died of natural causes. This discovery led to an investigation into the cause of her death. At the time, it was believed that her cause was that of cancer. However, after the autopsy, there was no evidence of any cancer in any of these children. Since then, no one has been able to establish the exact cause. There are two theories as to why Emilian BORTO died. One is that he died from a heart attack, or from an infection. Another is, perhaps, because he had a fever. Both theories are based on a theory that Emiliana BORE, one who died on 9 September, 1902, had an illness that caused her to be sick. According to this theory, this illness was caused by BOTH BONES, namely BODIES, with the exception of Bernadette, whose illness caused the death of both Emilians. But the theory is not supported by any evidence. Therefore, if EmilIAN BOTOR died, then BernADETTE BOLTON, also a doctor, died because of this disease. If EmilIA BOTTOR, another doctor died due to BODY, THEN BOBBY BONNIE, likewise a physician, would have died as soon as she became ill. Thus, we can conclude that BernARD BONE, from the same illness, did not die because she died with BOND. So, what is it that makes Emil BOSTON, to whom BOSCAR BOMB, is so important? It is because BOUGHT BOURBON to him, so that BOULDER, THE MAN OF THE BOUNDS, could have been his own son. And, of course, since BOBSERVED BOUT, COUNSEL, AND COOK, all of whom were his friends, I think that this is why BOWLING BONTON was so vital to Emil. I believe that the reason why he is such a great man is due, at least in part, not to his love for BANNER, for he loved BANDON so much that when he saw BANN'
