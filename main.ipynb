# %%
import warnings
warnings.filterwarnings("ignore")

from phaedra import split_sources, make_store, load_store, generate
from phaedra.sources.pdf import PDF
from phaedra.sources.text import Text

# %%
text = PDF.extract_text("bitcoin.pdf")
splits = split_sources([text])
store = make_store("bitcoin", splits)

# %%
store = load_store("bitcoin")

# %%
generate(
    store,
    "What is blockchain?",
)
# Out:
# Downloading (…)lve/main/config.json: 100%|██████████| 1.01k/1.01k [00:00<00:00, 1.43MB/s]
# Downloading (…)"pytorch_model.bin";: 100%|██████████| 526M/526M [00:45<00:00, 11.7MB/s]
# Downloading (…)okenizer_config.json: 100%|██████████| 560/560 [00:00<00:00, 327kB/s]
# Downloading (…)olve/main/vocab.json: 100%|██████████| 899k/899k [00:01<00:00, 807kB/s]
# Downloading (…)olve/main/merges.txt: 100%|██████████| 456k/456k [00:00<00:00, 1.28MB/s]
# Downloading (…)cial_tokens_map.json: 100%|██████████| 357/357 [00:00<00:00, 270kB/s]
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# '\n  What is a blockchain?\n"""\n\n'

# %%
text = Text.extract_text(
    """Gabriel Boric Font (born 11 February 1986) is a Chilean politician who is the current president of Chile, serving since 11 March 2022. Boric studied in the Faculty of Law at the University of Chile without completing his education, and was the president of the University of Chile Student Federation from 2011 to 2012. As a student representative, he became one of the leading figures of the 2011-2013 Chilean student protests. Boric was twice elected to the Chamber of Deputies representing the Magallanes and Antarctic district, first as an independent candidate in 2013 and then in 2017 as part of the Broad Front, a left-wing coalition he created with several other parties. He is a founding member of Social Convergence, which was formed in 2018 and is one of the constituent parties of Broad Front."""
)
splits = split_sources([text])
store = make_store("chile", splits)

generate(
    store,
    "Who is the president of Chile in 2023?",
    temperature=0.3,
)
# Out:
# Downloading (…)lve/main/config.json: 100%|██████████| 666/666 [00:00<00:00, 385kB/s]
# Downloading (…)"pytorch_model.bin";: 100%|██████████| 3.25G/3.25G [04:39<00:00, 11.6MB/s]
# Downloading (…)neration_config.json: 100%|██████████| 124/124 [00:00<00:00, 94.9kB/s]
# Downloading (…)olve/main/vocab.json: 100%|██████████| 1.04M/1.04M [00:03<00:00, 320kB/s]
# Downloading (…)olve/main/merges.txt: 100%|██████████| 456k/456k [00:00<00:00, 1.29MB/s]
# Downloading (…)/main/tokenizer.json: 100%|██████████| 1.36M/1.36M [00:02<00:00, 628kB/s]
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 'Chilean President Sebastian Pinera is currently serving his second term as president. Pineda was elected in 2016 with a majority of votes cast in a presidential election that was widely seen as a referendum on the country\'s economic and political situation. The country has been in recession since the end of 2015, with unemployment at over 20 percent. In 2017, the government announced a series of economic reforms, including a reduction in interest rates and a hike in public spending. On 23 January 2018, Pininga announced that he would not seek re-election in 2019. His successor will be chosen by the Chilean Congress, whose members will take office on 1 July 2018. President Pinesa\'s term ends in 2022.""\n,\n.\n'
